# %% [markdown]
# <p style=' font-size:32px; text-align:center'> <strong> Exercice de visualisation </strong>
# </p>

# %% [markdown]
# <p style='font-size:20px'> <strong>table des matières </strong></p>
#
# * [Je m'entraîne](#pour_bien_demarrer)
#     * [description du jeu de données](#info)
#     * [nettoyage](#clean)
#     * [visualisation univariée](#univ)
#     * [corrélation entre variable](#corr)

# %% [markdown]
# # Je m'entraîne <a class="anchor" id="description"></a>

# %% [markdown]
# > ## description du jeu de données <a class="anchor" id="repertoiredf"></a>

# %% [markdown]
# Dans cet exercice nous allons travailler sur le jeu de données data_cancer.
# L'objectif est de visualiser quelques variables et d'observer d'éventuelles correlations entre les variables explicatives.
# Avant de se lancer, il est necessaire de comprendre ce que le dataset contient. Aussi, dans cette première partie, vous commencerez par décrire votre dataset avant de procéder au netoyage et à quelques modifications dans les variables.

# %%
# importez ici toutes les librairies qui vous seront utiles pour l'ensemble des questions

# %%
#importez votre jeu de donnée

# %%
# Précisez sa taille, sa dimension

# %%
# Quel est le type de chacune des variables ?

# %%
#affichez quelques statistiques, sont elles toutes du même ordre de grandeur ?

# %%
#Quelles sont les valeurs uniques de la variable qualitative ? à quoi correspondent -elles ?

# %%
# y a t-il des valeurs nulles ? D'où proviennent elles ? comment y parer?

# %% [markdown]
# > ## nettoyage <a class="anchor" id="clean"></a>

# %% [markdown]
# Pour simplifier , nous allons travailler uniquement sur les colonnes _means
#
# Il existe plusieurs façons de sélectionner uniquement les 12 premières colonnes. essayez de le faire de différentes façons (et vérifiez bien que vous obtenez à chaque fois la même chose ! )

# %% [markdown]
#  **sélection de colonnes**

# %%
#solution 1 : avec la méthode .drop

# %%
#solution 2 : avec la methode .loc

# %%
#solution 3 : avec la methode .iloc

# %% [markdown]
# **remplacement de valeurs**

# %%
# remplacez l'encodage M et B par respectivement 'maligne' et 'benine'

# %%
#combien de tumeurs malignes et bénines avez vous?

# %% [markdown]
# **réorganisation des colonnes**

# %%
#on veut changer l'ordre des colonnes afin de préparer le dataset à une éventuelle utilisation pour prédiction,
#aussi on choisit de mettre la colonne ['diagnosis'] à la fin
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# **renommer des colonnes**

# %%
# on souhaite modifier le nom des colonnes en les traduisant en francais pour 
#'dianosis' en 'resultat' 
#colonne radius_mean --> rayon
#ect...

#vous devez obtenir le tableau suivant  :
# Out:
#            id  rayon  texture  perimetre    aire  regularite  compacite  \
# 0      842302  17.99    10.38     122.80  1001.0     0.11840    0.27760
# 1      842517  20.57    17.77     132.90  1326.0     0.08474    0.07864
# 2    84300903  19.69    21.25     130.00  1203.0     0.10960    0.15990
# 3    84348301  11.42    20.38      77.58   386.1     0.14250    0.28390
# 4    84358402  20.29    14.34     135.10  1297.0     0.10030    0.13280
# ..        ...    ...      ...        ...     ...         ...        ...
# 564    926424  21.56    22.39     142.00  1479.0     0.11100    0.11590
# 565    926682  20.13    28.25     131.20  1261.0     0.09780    0.10340
# 566    926954  16.60    28.08     108.30   858.1     0.08455    0.10230
# 567    927241  20.60    29.33     140.10  1265.0     0.11780    0.27700
# 568     92751   7.76    24.54      47.92   181.0     0.05263    0.04362
#
#      concavite  point_de_concavite  symetrie  dimension_fractale resultat
# ...

# %% [markdown]
# **ajout de colonne**

# %%
#on souhaite vérifier la cohérence des données de la colonne aire
#elle devrait correspondre à PiR²
# nous allons donc créer une nouvelle colonne dans le dataframe pour le vérifier  : 
# elle s'intitule 'verif' et correspond à la différence entre les valeurs de la colonne 'aire' moins celle de la colonne 'rayon'xPI²

#vous devriez obtenir les valeurs suivantes :
# Out:
# 0     -15.745361
# 1      -3.286077
# 2     -14.983220
# 3     -23.615204
# 4       3.656256
#          ...
# 564    18.682177
# 565   -12.026436
# 566    -7.597272
# 567   -68.166258
# 568    -8.179170
# Name: verif, Length: 569, dtype: float64

# %%
# comment évaluer cette différence? Est ce plausible?

# %%
# vous pouvez maintenant la supprimer du dataframe

# %% [markdown]
# **grouper**

# %%
# Nous souhaitons splitter les données en fonction du diagnostic du cancer 

# solution 1 : utilisez la methode groupby pour obtenir 2 dataframes distincts : 

# solution 2 : appliquez un masque pour obtenir les 2 dataframes 

cancer_benin = 
cancer_malin =

# %%
#on souhaite connaitre le rayon moyen, le rayon min et le rayon max des groupes précédents

#vous devrez obtenir les résultats suivants
#Que remarquez vous?
# Out:
#                mean    amin   amax
# resultat
# benine    12.146524   6.981  17.85
# maligne   17.462830  10.950  28.11

# %% [markdown]
# > ## visualisation univariée <a class="anchor" id="univ"></a>

# %% [markdown]
# Pour commencer nous allons déterminer quel est l'effectif de chaque catégorie de cancer à l'aide d'un camembert  puis nous ferons un barplot.
# Voici la doc pour les camembert :
#
# - https://plotly.com/python/pie-charts/
# - https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html
#
# Pour les barplot :
#
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
# - https://plotly.com/python/bar-charts/
# - https://seaborn.pydata.org/examples/grouped_barplot.html

# %%
# à l'aide de la librairie de votre choix, affichez un camembert représentant les % de chaque catégorie de cancer
# remarque :  (pour ajouter les effectifs, il est necessaire de les calculer )

# %%
# affichez le résultat cette fois ci en utilisant un barplot horizontal :

# %% [markdown]
# Dans cette partie nous allons visualiser des boxplot pour tenter de supprimer toutes les valeurs abbérantes.
#
# - https://seaborn.pydata.org/generated/seaborn.boxplot.html
# - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html
# - https://plotly.com/python/box-plots/
#
# *Attention*  toutes les valeurs aberrantes seront pour la suite supprimées UNIQUEMENT du dataframe d'analyse mais doivent être stockés dans le dataframe que l'on appelera donnees_error.

# %%
#réalisez 2 boxplot (dans la même visualisation) correspondant à colonne rayon moyen 
# une boxplot représentera les valeurs des tumeurs bénines et une autre celle des tumeurs maligne
# les points abbérants apparaîtront en rouge sur votre graphe

# %%
#une fois que vous avez visualisé les valeurs abérrantes, l'objectif est de les supprimer du dataframe d'analyse 
# mais ATTENTION ! avant de les supprimer, enregistrez les dans un dataframe à part appelé data_error
# vous ajouterez dans data_error une colonne précisant l'origine de l'erreur ( quelle est la colonne concernée)

data_error = 
# combien de lignes vous reste -il dans votre dataframe ? 
#combien de lignes avez vous dans votre dataframe data_error ?

# %%
#Faite la même chose avec la colonne périmètre, obtenez vous des valeurs abbérantes?

# %% [markdown]
# > ## visualisation multivariée et correlation <a class="anchor" id="univ"></a>

# %% [markdown]
# etudions maintenant la correlation entre les variables explicatives .
# Cela nous permettra de supprimer potentiellement des colonnes si l'on veut réaliser plus tard une modélisation pour prédire l'état du cancer.
# Pour cela enlevons les colonnes inutiles à savoir : id, resultat

# %%
cancer_corr =

# %%
# calculez les coefficients de correlations de votre nouveau dataframe à l'aide de la methode .corr()

# puis tracez une heatmap à l'aide de la librairie seaborn
# vous devriez obtenir une heatmap du genre : 
# vous pouvez jouer sur l'echelle de couleur pour plus de lisibilité

# %%
# Quelles sont les variables corrélées? cela vous semble normal? 
# Qu'est ce que cela signifie si vous souhaitez élaborer un modèle de prédiction?

# %%
#tracez les variables entre elles à l'aide d'un pairplot. Que peut -on conclure?
